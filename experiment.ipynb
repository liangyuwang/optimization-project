# %%
from train import train
from utils import plot_multi_loss_curve

# %%
# Linear -- (parameters: 1000)
num_epoch = 100
sd_loss = train(model='linear', optimizer='sd', num_epoch=num_epoch, print_log=False, test=False)
bfgs_loss = train(model='linear', optimizer='bfgs', num_epoch=num_epoch, print_log=False, test=False)
lbfgs_loss = train(model='linear', optimizer='lbfgs', num_epoch=num_epoch, print_log=False, test=False)
plot_multi_loss_curve([sd_loss, bfgs_loss, lbfgs_loss], ['sd', 'bfgs', 'lbfgs'], 'Linear loss curve')
# Out:
# ...
#  14%|█▍        | 14/100 [01:41<10:17,  7.18s/it]
# epoch 14 is converged
# epoch 14 is converged
# epoch 14 is converged
# ...
# 100%|██████████| 100/100 [12:08<00:00,  7.28s/it]

# %%
# MLP2 -- (parameters: 100*hidden_size+hidden_size+hidden_size*10+10=111*hidden_size+10)
num_epoch = 100
sd_loss = train(model='mlp2', optimizer='sd', num_epoch=num_epoch, print_log=False, test=False)
bfgs_loss = train(model='mlp2', optimizer='bfgs', num_epoch=num_epoch, print_log=False, test=False)
lbfgs_loss = train(model='mlp2', optimizer='lbfgs', num_epoch=num_epoch, print_log=False, test=False)
plot_multi_loss_curve([sd_loss, bfgs_loss, lbfgs_loss], ['sd', 'bfgs', 'lbfgs'], 'MLP2 loss curve')
# Out:
# ...
# 100%|██████████| 100/100 [12:12<00:00,  7.32s/it]
